# %% [markdown]
# <a href="https://colab.research.google.com/github/sasha110110/574-/blob/main/2%D0%BA%20%D0%BA%D0%BB%D0%B0%D1%81%D1%81/%D0%BE%D1%86%D0%B5%D0%BD%D0%BA%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Мои полиглотики. Вот оценки. Это отнюдь не равномерное распределение - когда всем все одинаково. Есть минусы, у кого-то даже 2. И с них в седующей четверти я буду очень строго спрашивать. И минусы могут превратиться в минус баллы.

# %% [markdown]
# Задание на каникулы дам через дня 4. Я размещу сообщение ВК в группе 2к, чтобы вы лишний раз не проверяли ссылку.

# %% [markdown]
# ![2 к оценки 1.png](data:image/png;base64,...)

# %% [markdown]
# ![2 к оценки 2.png](data:image/png;base64,...)

# %% [markdown]
# ![2 к оценки 3.png](data:image/png;base64,...)
