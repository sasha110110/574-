# %% [markdown]
# <a href="https://colab.research.google.com/github/sasha110110/574-/blob/main/3%D0%BA%20%D0%BA%D0%BB%D0%B0%D1%81%D1%81/%D0%BA%D0%B0%D0%BD%D0%B8%D0%BA%D1%83%D0%BB%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![семья.png](data:image/png;base64,...)

# %% [markdown]
# Теперь перейлем к комнате. Что есть у тебя в комнате, чего нет у Лизы?
#
#
# ![комната.png](data:image/png;base64,...)

# %% [markdown]
# ![лавка.png](data:image/png;base64,...)

# %% [markdown]
# Ребят, эта картина в Эрмитаже. Пойдете - посмотрите обязатльно! А еще там есть картина с 海鲜 хай сиэн - что это, кстати?

# %% [markdown]
# Проверь, все ли ключи узнаешь! Если нет - найди таблицу в интернете или скачай файо "Ключи"!

# %% [markdown]
# ![проверь ключи.png](data:image/png;base64,...)
