# %% [markdown]
# <a href="https://colab.research.google.com/github/sasha110110/574-/blob/main/3%D0%BA%20%D0%BA%D0%BB%D0%B0%D1%81%D1%81/05.04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Ребятки

# %% [markdown]
# ![05_1.png](data:image/png;base64,...)

# %% [markdown]
# ![05_2.png](data:image/png;base64,...)

# %% [markdown]
# * Еще видео про котика, который врет про дни недели.
# * https://www.youtube.com/watch?v=Wedf6JbwInM
